# %%
#AdaBoost classifier and regressor

# %%
#adaboost classifier
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import warnings 
warnings.filterwarnings('ignore')

# %%
X, y = make_classification(n_samples=1000, n_features=20, n_classes=2, random_state=1)

# %%
# Split dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
classifier = AdaBoostClassifier()
classifier.fit(X_train, y_train)
# Out:
# C:\Users\ajayk\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# AdaBoostClassifier()

# %%
# Make predictions
y_pred = classifier.predict(X_test)

# Evaluate the model
print("Current model performance:")
print(f"Accuracy: {accuracy_score(y_test, y_pred)}")
print("Classification Report:")
print(classification_report(y_test, y_pred))
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Current model performance:
# Accuracy: 0.806060606060606
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.83      0.80      0.82       176
#            1       0.78      0.81      0.80       154
#
#     accuracy                           0.81       330
#    macro avg       0.81      0.81      0.81       330
# weighted avg       0.81      0.81      0.81       330
#
# Confusion Matrix:
# [[141  35]
#  [ 29 125]]

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {
    'n_estimators': [50, 100, 200],
    'learning_rate': [0.01, 0.1, 1.0, 1.5, 2.0],
    'algorithm': ['SAMME', 'SAMME.R']
}
ada = AdaBoostClassifier()
clf = GridSearchCV(estimator=ada,param_grid=param_grid, cv=5, verbose = 3, n_jobs=-1) 
#if njobs = -1, you will not gget all fitting information

# %%
clf.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# GridSearchCV(cv=5, estimator=AdaBoostClassifier(), n_jobs=-1,
#              param_grid={'algorithm': ['SAMME', 'SAMME.R'],
#                          'learning_rate': [0.01, 0.1, 1.0, 1.5, 2.0],
#                          'n_estimators': [50, 100, 200]},
#              verbose=3)

# %%
clf.best_params_
# Out:
# {'algorithm': 'SAMME', 'learning_rate': 0.1, 'n_estimators': 200}

# %%
best_model = clf.best_estimator_

# %%
y_pred_tuned = best_model.predict(X_test)

# Evaluate the tuned model
print("Tuned model performance:")
print(f"Accuracy: {accuracy_score(y_test, y_pred_tuned)}")
print("Classification Report:")
print(classification_report(y_test, y_pred_tuned))
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred_tuned))
# Out:
# Tuned model performance:
# Accuracy: 0.8484848484848485
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.87      0.85      0.86       176
#            1       0.83      0.85      0.84       154
#
#     accuracy                           0.85       330
#    macro avg       0.85      0.85      0.85       330
# weighted avg       0.85      0.85      0.85       330
#
# Confusion Matrix:
# [[149  27]
#  [ 23 131]]

# %%
#adaboost regressor

from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.ensemble import AdaBoostRegressor
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %%
X, y = make_regression(n_samples=1000, n_features=2, noise =10,random_state=1)
# Split dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
regressor = AdaBoostRegressor()
regressor.fit(X_train, y_train)
# Out:
# AdaBoostRegressor()

# %%
y_pred = regressor.predict(X_test)

# Evaluate the model
print("Current model performance:")
print(f"R2 score: {r2_score(y_test, y_pred)}")
print(f"Mean Absolute Error: {mean_absolute_error(y_test, y_pred)}")
print(f"Mean Squared Error: {mean_squared_error(y_test, y_pred)}")
# Out:
# Current model performance:
# R2 score: 0.9641705203324348
# Mean Absolute Error: 12.554931647413753
# Mean Squared Error: 280.68588886138036

# %%
#hyperparameter tuning
from sklearn.model_selection import GridSearchCV
param_grid = {
    'n_estimators': [50, 100, 200],
    'learning_rate': [0.01, 0.1, 0.5, 1.0, 1.5],
    'loss': ['linear', 'square', 'exponential']
}
grid_search = GridSearchCV(estimator=regressor, param_grid=param_grid, cv = 5, verbose = 3)

# %%
grid_search
# Out:
# GridSearchCV(cv=5, estimator=AdaBoostRegressor(),
#              param_grid={'learning_rate': [0.01, 0.1, 0.5, 1.0, 1.5],
#                          'loss': ['linear', 'square', 'exponential'],
#                          'n_estimators': [50, 100, 200]},
#              verbose=3)

# %%
grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 45 candidates, totalling 225 fits
# [CV 1/5] END learning_rate=0.01, loss=linear, n_estimators=50;, score=0.918 total time=   0.0s
# [CV 2/5] END learning_rate=0.01, loss=linear, n_estimators=50;, score=0.926 total time=   0.0s
# [CV 3/5] END learning_rate=0.01, loss=linear, n_estimators=50;, score=0.940 total time=   0.0s
# [CV 4/5] END learning_rate=0.01, loss=linear, n_estimators=50;, score=0.944 total time=   0.0s
# [CV 5/5] END learning_rate=0.01, loss=linear, n_estimators=50;, score=0.937 total time=   0.0s
# [CV 1/5] END learning_rate=0.01, loss=linear, n_estimators=100;, score=0.925 total time=   0.0s
# [CV 2/5] END learning_rate=0.01, loss=linear, n_estimators=100;, score=0.929 total time=   0.0s
# [CV 3/5] END learning_rate=0.01, loss=linear, n_estimators=100;, score=0.940 total time=   0.0s
# [CV 4/5] END learning_rate=0.01, loss=linear, n_estimators=100;, score=0.942 total time=   0.0s
# [CV 5/5] END learning_rate=0.01, loss=linear, n_estimators=100;, score=0.936 total time=   0.0s
# [CV 1/5] END learning_rate=0.01, loss=linear, n_estimators=200;, score=0.927 total time=   0.2s
# [CV 2/5] END learning_rate=0.01, loss=linear, n_estimators=200;, score=0.932 total time=   0.2s
# [CV 3/5] END learning_rate=0.01, loss=linear, n_estimators=200;, score=0.944 total time=   0.2s
# [CV 4/5] END learning_rate=0.01, loss=linear, n_estimators=200;, score=0.944 total time=   0.2s
# [CV 5/5] END learning_rate=0.01, loss=linear, n_estimators=200;, score=0.939 total time=   0.2s
# [CV 1/5] END learning_rate=0.01, loss=square, n_estimators=50;, score=0.920 total time=   0.0s
# [CV 2/5] END learning_rate=0.01, loss=square, n_estimators=50;, score=0.924 total time=   0.0s
# [CV 3/5] END learning_rate=0.01, loss=square, n_estimators=50;, score=0.939 total time=   0.0s
# [CV 4/5] END learning_rate=0.01, loss=square, n_estimators=50;, score=0.947 total time=   0.0s
# [CV 5/5] END learning_rate=0.01, loss=square, n_estimators=50;, score=0.934 total time=   0.0s
# [CV 1/5] END learning_rate=0.01, loss=square, n_estimators=100;, score=0.925 total time=   0.0s
# [CV 2/5] END learning_rate=0.01, loss=square, n_estimators=100;, score=0.929 total time=   0.0s
# [CV 3/5] END learning_rate=0.01, loss=square, n_estimators=100;, score=0.938 total time=   0.0s
# [CV 4/5] END learning_rate=0.01, loss=square, n_estimators=100;, score=0.942 total time=   0.0s
# [CV 5/5] END learning_rate=0.01, loss=square, n_estimators=100;, score=0.937 total time=   0.0s
# [CV 1/5] END learning_rate=0.01, loss=square, n_estimators=200;, score=0.929 total time=   0.2s
# [CV 2/5] END learning_rate=0.01, loss=square, n_estimators=200;, score=0.937 total time=   0.2s
# [CV 3/5] END learning_rate=0.01, loss=square, n_estimators=200;, score=0.947 total time=   0.2s
# [CV 4/5] END learning_rate=0.01, loss=square, n_estimators=200;, score=0.943 total time=   0.2s
# [CV 5/5] END learning_rate=0.01, loss=square, n_estimators=200;, score=0.940 total time=   0.2s
# [CV 1/5] END learning_rate=0.01, loss=exponential, n_estimators=50;, score=0.917 total time=   0.0s
# [CV 2/5] END learning_rate=0.01, loss=exponential, n_estimators=50;, score=0.926 total time=   0.0s
# [CV 3/5] END learning_rate=0.01, loss=exponential, n_estimators=50;, score=0.934 total time=   0.0s
# [CV 4/5] END learning_rate=0.01, loss=exponential, n_estimators=50;, score=0.943 total time=   0.0s
# [CV 5/5] END learning_rate=0.01, loss=exponential, n_estimators=50;, score=0.936 total time=   0.0s
# [CV 1/5] END learning_rate=0.01, loss=exponential, n_estimators=100;, score=0.925 total time=   0.0s
# [CV 2/5] END learning_rate=0.01, loss=exponential, n_estimators=100;, score=0.928 total time=   0.0s
# [CV 3/5] END learning_rate=0.01, loss=exponential, n_estimators=100;, score=0.941 total time=   0.0s
# [CV 4/5] END learning_rate=0.01, loss=exponential, n_estimators=100;, score=0.945 total time=   0.0s
# [CV 5/5] END learning_rate=0.01, loss=exponential, n_estimators=100;, score=0.938 total time=   0.0s
# [CV 1/5] END learning_rate=0.01, loss=exponential, n_estimators=200;, score=0.924 total time=   0.2s
# [CV 2/5] END learning_rate=0.01, loss=exponential, n_estimators=200;, score=0.929 total time=   0.2s
# [CV 3/5] END learning_rate=0.01, loss=exponential, n_estimators=200;, score=0.943 total time=   0.2s
# [CV 4/5] END learning_rate=0.01, loss=exponential, n_estimators=200;, score=0.945 total time=   0.2s
# [CV 5/5] END learning_rate=0.01, loss=exponential, n_estimators=200;, score=0.938 total time=   0.2s
# [CV 1/5] END learning_rate=0.1, loss=linear, n_estimators=50;, score=0.928 total time=   0.0s
# [CV 2/5] END learning_rate=0.1, loss=linear, n_estimators=50;, score=0.940 total time=   0.0s
# [CV 3/5] END learning_rate=0.1, loss=linear, n_estimators=50;, score=0.951 total time=   0.0s
# [CV 4/5] END learning_rate=0.1, loss=linear, n_estimators=50;, score=0.948 total time=   0.0s
# [CV 5/5] END learning_rate=0.1, loss=linear, n_estimators=50;, score=0.940 total time=   0.0s
# [CV 1/5] END learning_rate=0.1, loss=linear, n_estimators=100;, score=0.939 total time=   0.0s
# [CV 2/5] END learning_rate=0.1, loss=linear, n_estimators=100;, score=0.947 total time=   0.1s
# [CV 3/5] END learning_rate=0.1, loss=linear, n_estimators=100;, score=0.957 total time=   0.1s
# [CV 4/5] END learning_rate=0.1, loss=linear, n_estimators=100;, score=0.958 total time=   0.1s
# [CV 5/5] END learning_rate=0.1, loss=linear, n_estimators=100;, score=0.946 total time=   0.1s
# [CV 1/5] END learning_rate=0.1, loss=linear, n_estimators=200;, score=0.947 total time=   0.2s
# [CV 2/5] END learning_rate=0.1, loss=linear, n_estimators=200;, score=0.954 total time=   0.2s
# [CV 3/5] END learning_rate=0.1, loss=linear, n_estimators=200;, score=0.964 total time=   0.2s
# [CV 4/5] END learning_rate=0.1, loss=linear, n_estimators=200;, score=0.965 total time=   0.2s
# [CV 5/5] END learning_rate=0.1, loss=linear, n_estimators=200;, score=0.955 total time=   0.2s
# [CV 1/5] END learning_rate=0.1, loss=square, n_estimators=50;, score=0.933 total time=   0.0s
# [CV 2/5] END learning_rate=0.1, loss=square, n_estimators=50;, score=0.947 total time=   0.0s
# [CV 3/5] END learning_rate=0.1, loss=square, n_estimators=50;, score=0.955 total time=   0.0s
# [CV 4/5] END learning_rate=0.1, loss=square, n_estimators=50;, score=0.949 total time=   0.0s
# [CV 5/5] END learning_rate=0.1, loss=square, n_estimators=50;, score=0.943 total time=   0.0s
# [CV 1/5] END learning_rate=0.1, loss=square, n_estimators=100;, score=0.945 total time=   0.1s
# [CV 2/5] END learning_rate=0.1, loss=square, n_estimators=100;, score=0.952 total time=   0.1s
# [CV 3/5] END learning_rate=0.1, loss=square, n_estimators=100;, score=0.961 total time=   0.0s
# [CV 4/5] END learning_rate=0.1, loss=square, n_estimators=100;, score=0.961 total time=   0.0s
# [CV 5/5] END learning_rate=0.1, loss=square, n_estimators=100;, score=0.951 total time=   0.0s
# [CV 1/5] END learning_rate=0.1, loss=square, n_estimators=200;, score=0.953 total time=   0.2s
# [CV 2/5] END learning_rate=0.1, loss=square, n_estimators=200;, score=0.957 total time=   0.2s
# [CV 3/5] END learning_rate=0.1, loss=square, n_estimators=200;, score=0.965 total time=   0.2s
# [CV 4/5] END learning_rate=0.1, loss=square, n_estimators=200;, score=0.968 total time=   0.2s
# [CV 5/5] END learning_rate=0.1, loss=square, n_estimators=200;, score=0.959 total time=   0.2s
# [CV 1/5] END learning_rate=0.1, loss=exponential, n_estimators=50;, score=0.933 total time=   0.0s
# [CV 2/5] END learning_rate=0.1, loss=exponential, n_estimators=50;, score=0.936 total time=   0.0s
# [CV 3/5] END learning_rate=0.1, loss=exponential, n_estimators=50;, score=0.945 total time=   0.0s
# [CV 4/5] END learning_rate=0.1, loss=exponential, n_estimators=50;, score=0.948 total time=   0.0s
# [CV 5/5] END learning_rate=0.1, loss=exponential, n_estimators=50;, score=0.940 total time=   0.0s
# [CV 1/5] END learning_rate=0.1, loss=exponential, n_estimators=100;, score=0.935 total time=   0.1s
# [CV 2/5] END learning_rate=0.1, loss=exponential, n_estimators=100;, score=0.946 total time=   0.0s
# [CV 3/5] END learning_rate=0.1, loss=exponential, n_estimators=100;, score=0.955 total time=   0.0s
# [CV 4/5] END learning_rate=0.1, loss=exponential, n_estimators=100;, score=0.955 total time=   0.0s
# [CV 5/5] END learning_rate=0.1, loss=exponential, n_estimators=100;, score=0.948 total time=   0.0s
# [CV 1/5] END learning_rate=0.1, loss=exponential, n_estimators=200;, score=0.947 total time=   0.2s
# [CV 2/5] END learning_rate=0.1, loss=exponential, n_estimators=200;, score=0.955 total time=   0.2s
# [CV 3/5] END learning_rate=0.1, loss=exponential, n_estimators=200;, score=0.963 total time=   0.2s
# [CV 4/5] END learning_rate=0.1, loss=exponential, n_estimators=200;, score=0.964 total time=   0.2s
# [CV 5/5] END learning_rate=0.1, loss=exponential, n_estimators=200;, score=0.955 total time=   0.2s
# [CV 1/5] END learning_rate=0.5, loss=linear, n_estimators=50;, score=0.949 total time=   0.0s
# [CV 2/5] END learning_rate=0.5, loss=linear, n_estimators=50;, score=0.958 total time=   0.0s
# [CV 3/5] END learning_rate=0.5, loss=linear, n_estimators=50;, score=0.963 total time=   0.0s
# [CV 4/5] END learning_rate=0.5, loss=linear, n_estimators=50;, score=0.966 total time=   0.0s
# [CV 5/5] END learning_rate=0.5, loss=linear, n_estimators=50;, score=0.958 total time=   0.0s
# [CV 1/5] END learning_rate=0.5, loss=linear, n_estimators=100;, score=0.956 total time=   0.0s
# [CV 2/5] END learning_rate=0.5, loss=linear, n_estimators=100;, score=0.959 total time=   0.1s
# [CV 3/5] END learning_rate=0.5, loss=linear, n_estimators=100;, score=0.968 total time=   0.1s
# [CV 4/5] END learning_rate=0.5, loss=linear, n_estimators=100;, score=0.972 total time=   0.0s
# [CV 5/5] END learning_rate=0.5, loss=linear, n_estimators=100;, score=0.962 total time=   0.0s
# [CV 1/5] END learning_rate=0.5, loss=linear, n_estimators=200;, score=0.960 total time=   0.2s
# [CV 2/5] END learning_rate=0.5, loss=linear, n_estimators=200;, score=0.961 total time=   0.2s
# [CV 3/5] END learning_rate=0.5, loss=linear, n_estimators=200;, score=0.969 total time=   0.2s
# [CV 4/5] END learning_rate=0.5, loss=linear, n_estimators=200;, score=0.975 total time=   0.2s
# [CV 5/5] END learning_rate=0.5, loss=linear, n_estimators=200;, score=0.967 total time=   0.2s
# [CV 1/5] END learning_rate=0.5, loss=square, n_estimators=50;, score=0.956 total time=   0.0s
# [CV 2/5] END learning_rate=0.5, loss=square, n_estimators=50;, score=0.962 total time=   0.0s
# [CV 3/5] END learning_rate=0.5, loss=square, n_estimators=50;, score=0.963 total time=   0.0s
# [CV 4/5] END learning_rate=0.5, loss=square, n_estimators=50;, score=0.969 total time=   0.0s
# [CV 5/5] END learning_rate=0.5, loss=square, n_estimators=50;, score=0.960 total time=   0.0s
# [CV 1/5] END learning_rate=0.5, loss=square, n_estimators=100;, score=0.960 total time=   0.0s
# [CV 2/5] END learning_rate=0.5, loss=square, n_estimators=100;, score=0.961 total time=   0.1s
# [CV 3/5] END learning_rate=0.5, loss=square, n_estimators=100;, score=0.968 total time=   0.0s
# [CV 4/5] END learning_rate=0.5, loss=square, n_estimators=100;, score=0.970 total time=   0.1s
# [CV 5/5] END learning_rate=0.5, loss=square, n_estimators=100;, score=0.966 total time=   0.0s
# [CV 1/5] END learning_rate=0.5, loss=square, n_estimators=200;, score=0.960 total time=   0.2s
# [CV 2/5] END learning_rate=0.5, loss=square, n_estimators=200;, score=0.961 total time=   0.2s
# [CV 3/5] END learning_rate=0.5, loss=square, n_estimators=200;, score=0.969 total time=   0.2s
# [CV 4/5] END learning_rate=0.5, loss=square, n_estimators=200;, score=0.971 total time=   0.2s
# [CV 5/5] END learning_rate=0.5, loss=square, n_estimators=200;, score=0.970 total time=   0.2s
# [CV 1/5] END learning_rate=0.5, loss=exponential, n_estimators=50;, score=0.950 total time=   0.0s
# [CV 2/5] END learning_rate=0.5, loss=exponential, n_estimators=50;, score=0.955 total time=   0.0s
# [CV 3/5] END learning_rate=0.5, loss=exponential, n_estimators=50;, score=0.965 total time=   0.0s
# [CV 4/5] END learning_rate=0.5, loss=exponential, n_estimators=50;, score=0.966 total time=   0.0s
# [CV 5/5] END learning_rate=0.5, loss=exponential, n_estimators=50;, score=0.955 total time=   0.0s
# [CV 1/5] END learning_rate=0.5, loss=exponential, n_estimators=100;, score=0.957 total time=   0.0s
# [CV 2/5] END learning_rate=0.5, loss=exponential, n_estimators=100;, score=0.961 total time=   0.1s
# [CV 3/5] END learning_rate=0.5, loss=exponential, n_estimators=100;, score=0.968 total time=   0.0s
# [CV 4/5] END learning_rate=0.5, loss=exponential, n_estimators=100;, score=0.970 total time=   0.0s
# [CV 5/5] END learning_rate=0.5, loss=exponential, n_estimators=100;, score=0.964 total time=   0.0s
# [CV 1/5] END learning_rate=0.5, loss=exponential, n_estimators=200;, score=0.963 total time=   0.2s
# [CV 2/5] END learning_rate=0.5, loss=exponential, n_estimators=200;, score=0.958 total time=   0.2s
# [CV 3/5] END learning_rate=0.5, loss=exponential, n_estimators=200;, score=0.969 total time=   0.2s
# [CV 4/5] END learning_rate=0.5, loss=exponential, n_estimators=200;, score=0.974 total time=   0.2s
# [CV 5/5] END learning_rate=0.5, loss=exponential, n_estimators=200;, score=0.966 total time=   0.2s
# [CV 1/5] END learning_rate=1.0, loss=linear, n_estimators=50;, score=0.957 total time=   0.0s
# [CV 2/5] END learning_rate=1.0, loss=linear, n_estimators=50;, score=0.959 total time=   0.0s
# [CV 3/5] END learning_rate=1.0, loss=linear, n_estimators=50;, score=0.968 total time=   0.0s
# [CV 4/5] END learning_rate=1.0, loss=linear, n_estimators=50;, score=0.970 total time=   0.0s
# [CV 5/5] END learning_rate=1.0, loss=linear, n_estimators=50;, score=0.961 total time=   0.0s
# [CV 1/5] END learning_rate=1.0, loss=linear, n_estimators=100;, score=0.961 total time=   0.0s
# [CV 2/5] END learning_rate=1.0, loss=linear, n_estimators=100;, score=0.961 total time=   0.0s
# [CV 3/5] END learning_rate=1.0, loss=linear, n_estimators=100;, score=0.970 total time=   0.0s
# [CV 4/5] END learning_rate=1.0, loss=linear, n_estimators=100;, score=0.971 total time=   0.0s
# [CV 5/5] END learning_rate=1.0, loss=linear, n_estimators=100;, score=0.966 total time=   0.1s
# [CV 1/5] END learning_rate=1.0, loss=linear, n_estimators=200;, score=0.963 total time=   0.2s
# [CV 2/5] END learning_rate=1.0, loss=linear, n_estimators=200;, score=0.962 total time=   0.2s
# [CV 3/5] END learning_rate=1.0, loss=linear, n_estimators=200;, score=0.972 total time=   0.2s
# [CV 4/5] END learning_rate=1.0, loss=linear, n_estimators=200;, score=0.975 total time=   0.2s
# [CV 5/5] END learning_rate=1.0, loss=linear, n_estimators=200;, score=0.969 total time=   0.2s
# [CV 1/5] END learning_rate=1.0, loss=square, n_estimators=50;, score=0.960 total time=   0.0s
# [CV 2/5] END learning_rate=1.0, loss=square, n_estimators=50;, score=0.964 total time=   0.0s
# [CV 3/5] END learning_rate=1.0, loss=square, n_estimators=50;, score=0.970 total time=   0.0s
# [CV 4/5] END learning_rate=1.0, loss=square, n_estimators=50;, score=0.970 total time=   0.0s
# [CV 5/5] END learning_rate=1.0, loss=square, n_estimators=50;, score=0.966 total time=   0.0s
# [CV 1/5] END learning_rate=1.0, loss=square, n_estimators=100;, score=0.962 total time=   0.0s
# [CV 2/5] END learning_rate=1.0, loss=square, n_estimators=100;, score=0.967 total time=   0.0s
# [CV 3/5] END learning_rate=1.0, loss=square, n_estimators=100;, score=0.973 total time=   0.0s
# [CV 4/5] END learning_rate=1.0, loss=square, n_estimators=100;, score=0.974 total time=   0.0s
# [CV 5/5] END learning_rate=1.0, loss=square, n_estimators=100;, score=0.971 total time=   0.0s
# [CV 1/5] END learning_rate=1.0, loss=square, n_estimators=200;, score=0.965 total time=   0.2s
# [CV 2/5] END learning_rate=1.0, loss=square, n_estimators=200;, score=0.969 total time=   0.2s
# [CV 3/5] END learning_rate=1.0, loss=square, n_estimators=200;, score=0.973 total time=   0.2s
# [CV 4/5] END learning_rate=1.0, loss=square, n_estimators=200;, score=0.974 total time=   0.2s
# [CV 5/5] END learning_rate=1.0, loss=square, n_estimators=200;, score=0.972 total time=   0.2s
# [CV 1/5] END learning_rate=1.0, loss=exponential, n_estimators=50;, score=0.956 total time=   0.0s
# [CV 2/5] END learning_rate=1.0, loss=exponential, n_estimators=50;, score=0.962 total time=   0.0s
# [CV 3/5] END learning_rate=1.0, loss=exponential, n_estimators=50;, score=0.967 total time=   0.0s
# [CV 4/5] END learning_rate=1.0, loss=exponential, n_estimators=50;, score=0.971 total time=   0.0s
# [CV 5/5] END learning_rate=1.0, loss=exponential, n_estimators=50;, score=0.962 total time=   0.0s
# [CV 1/5] END learning_rate=1.0, loss=exponential, n_estimators=100;, score=0.962 total time=   0.0s
# [CV 2/5] END learning_rate=1.0, loss=exponential, n_estimators=100;, score=0.961 total time=   0.0s
# [CV 3/5] END learning_rate=1.0, loss=exponential, n_estimators=100;, score=0.971 total time=   0.0s
# [CV 4/5] END learning_rate=1.0, loss=exponential, n_estimators=100;, score=0.973 total time=   0.0s
# [CV 5/5] END learning_rate=1.0, loss=exponential, n_estimators=100;, score=0.967 total time=   0.0s
# [CV 1/5] END learning_rate=1.0, loss=exponential, n_estimators=200;, score=0.964 total time=   0.2s
# [CV 2/5] END learning_rate=1.0, loss=exponential, n_estimators=200;, score=0.961 total time=   0.2s
# [CV 3/5] END learning_rate=1.0, loss=exponential, n_estimators=200;, score=0.972 total time=   0.2s
# [CV 4/5] END learning_rate=1.0, loss=exponential, n_estimators=200;, score=0.976 total time=   0.2s
# [CV 5/5] END learning_rate=1.0, loss=exponential, n_estimators=200;, score=0.966 total time=   0.2s
# [CV 1/5] END learning_rate=1.5, loss=linear, n_estimators=50;, score=0.958 total time=   0.0s
# [CV 2/5] END learning_rate=1.5, loss=linear, n_estimators=50;, score=0.959 total time=   0.0s
# [CV 3/5] END learning_rate=1.5, loss=linear, n_estimators=50;, score=0.971 total time=   0.0s
# [CV 4/5] END learning_rate=1.5, loss=linear, n_estimators=50;, score=0.973 total time=   0.0s
# [CV 5/5] END learning_rate=1.5, loss=linear, n_estimators=50;, score=0.967 total time=   0.0s
# [CV 1/5] END learning_rate=1.5, loss=linear, n_estimators=100;, score=0.963 total time=   0.0s
# [CV 2/5] END learning_rate=1.5, loss=linear, n_estimators=100;, score=0.965 total time=   0.0s
# [CV 3/5] END learning_rate=1.5, loss=linear, n_estimators=100;, score=0.972 total time=   0.0s
# [CV 4/5] END learning_rate=1.5, loss=linear, n_estimators=100;, score=0.973 total time=   0.0s
# [CV 5/5] END learning_rate=1.5, loss=linear, n_estimators=100;, score=0.967 total time=   0.0s
# [CV 1/5] END learning_rate=1.5, loss=linear, n_estimators=200;, score=0.965 total time=   0.2s
# [CV 2/5] END learning_rate=1.5, loss=linear, n_estimators=200;, score=0.966 total time=   0.2s
# [CV 3/5] END learning_rate=1.5, loss=linear, n_estimators=200;, score=0.974 total time=   0.2s
# [CV 4/5] END learning_rate=1.5, loss=linear, n_estimators=200;, score=0.975 total time=   0.2s
# [CV 5/5] END learning_rate=1.5, loss=linear, n_estimators=200;, score=0.968 total time=   0.2s
# [CV 1/5] END learning_rate=1.5, loss=square, n_estimators=50;, score=0.961 total time=   0.0s
# [CV 2/5] END learning_rate=1.5, loss=square, n_estimators=50;, score=0.965 total time=   0.0s
# [CV 3/5] END learning_rate=1.5, loss=square, n_estimators=50;, score=0.970 total time=   0.0s
# [CV 4/5] END learning_rate=1.5, loss=square, n_estimators=50;, score=0.972 total time=   0.0s
# [CV 5/5] END learning_rate=1.5, loss=square, n_estimators=50;, score=0.969 total time=   0.0s
# [CV 1/5] END learning_rate=1.5, loss=square, n_estimators=100;, score=0.966 total time=   0.0s
# [CV 2/5] END learning_rate=1.5, loss=square, n_estimators=100;, score=0.970 total time=   0.0s
# [CV 3/5] END learning_rate=1.5, loss=square, n_estimators=100;, score=0.974 total time=   0.0s
# [CV 4/5] END learning_rate=1.5, loss=square, n_estimators=100;, score=0.976 total time=   0.0s
# [CV 5/5] END learning_rate=1.5, loss=square, n_estimators=100;, score=0.974 total time=   0.0s
# [CV 1/5] END learning_rate=1.5, loss=square, n_estimators=200;, score=0.965 total time=   0.2s
# [CV 2/5] END learning_rate=1.5, loss=square, n_estimators=200;, score=0.969 total time=   0.2s
# [CV 3/5] END learning_rate=1.5, loss=square, n_estimators=200;, score=0.973 total time=   0.2s
# [CV 4/5] END learning_rate=1.5, loss=square, n_estimators=200;, score=0.976 total time=   0.2s
# [CV 5/5] END learning_rate=1.5, loss=square, n_estimators=200;, score=0.973 total time=   0.2s
# [CV 1/5] END learning_rate=1.5, loss=exponential, n_estimators=50;, score=0.960 total time=   0.0s
# [CV 2/5] END learning_rate=1.5, loss=exponential, n_estimators=50;, score=0.957 total time=   0.0s
# [CV 3/5] END learning_rate=1.5, loss=exponential, n_estimators=50;, score=0.970 total time=   0.0s
# [CV 4/5] END learning_rate=1.5, loss=exponential, n_estimators=50;, score=0.974 total time=   0.0s
# [CV 5/5] END learning_rate=1.5, loss=exponential, n_estimators=50;, score=0.964 total time=   0.0s
# [CV 1/5] END learning_rate=1.5, loss=exponential, n_estimators=100;, score=0.964 total time=   0.0s
# [CV 2/5] END learning_rate=1.5, loss=exponential, n_estimators=100;, score=0.965 total time=   0.0s
# [CV 3/5] END learning_rate=1.5, loss=exponential, n_estimators=100;, score=0.972 total time=   0.0s
# [CV 4/5] END learning_rate=1.5, loss=exponential, n_estimators=100;, score=0.975 total time=   0.0s
# [CV 5/5] END learning_rate=1.5, loss=exponential, n_estimators=100;, score=0.967 total time=   0.0s
# [CV 1/5] END learning_rate=1.5, loss=exponential, n_estimators=200;, score=0.966 total time=   0.2s
# [CV 2/5] END learning_rate=1.5, loss=exponential, n_estimators=200;, score=0.964 total time=   0.2s
# [CV 3/5] END learning_rate=1.5, loss=exponential, n_estimators=200;, score=0.972 total time=   0.2s
# [CV 4/5] END learning_rate=1.5, loss=exponential, n_estimators=200;, score=0.974 total time=   0.2s
# [CV 5/5] END learning_rate=1.5, loss=exponential, n_estimators=200;, score=0.968 total time=   0.2s
# GridSearchCV(cv=5, estimator=AdaBoostRegressor(),
#              param_grid={'learning_rate': [0.01, 0.1, 0.5, 1.0, 1.5],
#                          'loss': ['linear', 'square', 'exponential'],
#                          'n_estimators': [50, 100, 200]},
#              verbose=3)

# %%
grid_search.best_params_
# Out:
# {'learning_rate': 1.5, 'loss': 'square', 'n_estimators': 100}

# %%
best_model = grid_search.best_estimator_
y_pred_tuned = best_model.predict(X_test)

# Evaluate the tuned model
print("Tuned model performance:")
print(f"R2 score: {r2_score(y_test, y_pred_tuned)}")
print(f"Mean Absolute Error: {mean_absolute_error(y_test, y_pred_tuned)}")
print(f"Mean Squared Error: {mean_squared_error(y_test, y_pred_tuned)}")
# Out:
# Tuned model performance:
# R2 score: 0.9683238022323749
# Mean Absolute Error: 11.926031150871824
# Mean Squared Error: 248.14933983547002
