# %%
#Gradient boosting classifier

from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
# Generate dataset
X, y = make_classification(n_samples=1000, n_features=20, n_classes=2, random_state=1)

# Split dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=1)

# %%
clf = GradientBoostingClassifier()
clf.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier()

# %%
# Make predictions
y_pred = clf.predict(X_test)

# Evaluate the model
print("Current model performance:")
print(f"Accuracy: {accuracy_score(y_test, y_pred)}")
print("Classification Report:")
print(classification_report(y_test, y_pred))
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Current model performance:
# Accuracy: 0.8545454545454545
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.84      0.85      0.85       154
#            1       0.87      0.86      0.86       176
#
#     accuracy                           0.85       330
#    macro avg       0.85      0.85      0.85       330
# weighted avg       0.85      0.85      0.85       330
#
# Confusion Matrix:
# [[131  23]
#  [ 25 151]]

# %%
#hyperpraremeter tuning
from sklearn.model_selection import GridSearchCV

# Define the parameter grid
param_grid = {
    'n_estimators': [100, 200, 300],
    'learning_rate': [0.01, 0.1, 0.05, 0.2],
#     'max_depth': [3, 4, 5],
#     'subsample': [0.8, 0.9, 1.0],
#     'min_samples_split': [2, 5, 10],
#     'min_samples_leaf': [1, 2, 4]
}

# %%
gbc = GradientBoostingClassifier()
grid_search = GridSearchCV(estimator = gbc, param_grid=param_grid, cv = 5, verbose=3)

# %%
grid_search
# Out:
# GridSearchCV(cv=5, estimator=GradientBoostingClassifier(),
#              param_grid={'learning_rate': [0.01, 0.1, 0.05, 0.2],
#                          'n_estimators': [100, 200, 300]},
#              verbose=3)

# %%
grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV 1/5] END learning_rate=0.01, n_estimators=100;, score=0.881 total time=   0.2s
# [CV 2/5] END learning_rate=0.01, n_estimators=100;, score=0.903 total time=   0.3s
# [CV 3/5] END learning_rate=0.01, n_estimators=100;, score=0.836 total time=   0.3s
# [CV 4/5] END learning_rate=0.01, n_estimators=100;, score=0.858 total time=   0.3s
# [CV 5/5] END learning_rate=0.01, n_estimators=100;, score=0.821 total time=   0.3s
# [CV 1/5] END learning_rate=0.01, n_estimators=200;, score=0.881 total time=   0.7s
# [CV 2/5] END learning_rate=0.01, n_estimators=200;, score=0.888 total time=   0.7s
# [CV 3/5] END learning_rate=0.01, n_estimators=200;, score=0.858 total time=   0.6s
# [CV 4/5] END learning_rate=0.01, n_estimators=200;, score=0.858 total time=   0.7s
# [CV 5/5] END learning_rate=0.01, n_estimators=200;, score=0.821 total time=   0.6s
# [CV 1/5] END learning_rate=0.01, n_estimators=300;, score=0.888 total time=   1.0s
# [CV 2/5] END learning_rate=0.01, n_estimators=300;, score=0.896 total time=   1.0s
# [CV 3/5] END learning_rate=0.01, n_estimators=300;, score=0.858 total time=   1.1s
# [CV 4/5] END learning_rate=0.01, n_estimators=300;, score=0.851 total time=   1.0s
# [CV 5/5] END learning_rate=0.01, n_estimators=300;, score=0.821 total time=   1.1s
# [CV 1/5] END learning_rate=0.1, n_estimators=100;, score=0.873 total time=   0.3s
# [CV 2/5] END learning_rate=0.1, n_estimators=100;, score=0.881 total time=   0.3s
# [CV 3/5] END learning_rate=0.1, n_estimators=100;, score=0.851 total time=   0.3s
# [CV 4/5] END learning_rate=0.1, n_estimators=100;, score=0.828 total time=   0.3s
# [CV 5/5] END learning_rate=0.1, n_estimators=100;, score=0.821 total time=   0.3s
# [CV 1/5] END learning_rate=0.1, n_estimators=200;, score=0.881 total time=   0.7s
# [CV 2/5] END learning_rate=0.1, n_estimators=200;, score=0.888 total time=   0.6s
# [CV 3/5] END learning_rate=0.1, n_estimators=200;, score=0.836 total time=   0.7s
# [CV 4/5] END learning_rate=0.1, n_estimators=200;, score=0.828 total time=   0.7s
# [CV 5/5] END learning_rate=0.1, n_estimators=200;, score=0.821 total time=   0.7s
# [CV 1/5] END learning_rate=0.1, n_estimators=300;, score=0.881 total time=   1.1s
# [CV 2/5] END learning_rate=0.1, n_estimators=300;, score=0.888 total time=   1.1s
# [CV 3/5] END learning_rate=0.1, n_estimators=300;, score=0.828 total time=   1.1s
# [CV 4/5] END learning_rate=0.1, n_estimators=300;, score=0.836 total time=   1.0s
# [CV 5/5] END learning_rate=0.1, n_estimators=300;, score=0.821 total time=   1.0s
# [CV 1/5] END learning_rate=0.05, n_estimators=100;, score=0.881 total time=   0.3s
# [CV 2/5] END learning_rate=0.05, n_estimators=100;, score=0.888 total time=   0.3s
# [CV 3/5] END learning_rate=0.05, n_estimators=100;, score=0.851 total time=   0.3s
# [CV 4/5] END learning_rate=0.05, n_estimators=100;, score=0.851 total time=   0.3s
# [CV 5/5] END learning_rate=0.05, n_estimators=100;, score=0.821 total time=   0.3s
# [CV 1/5] END learning_rate=0.05, n_estimators=200;, score=0.881 total time=   0.7s
# [CV 2/5] END learning_rate=0.05, n_estimators=200;, score=0.888 total time=   0.6s
# [CV 3/5] END learning_rate=0.05, n_estimators=200;, score=0.836 total time=   0.6s
# [CV 4/5] END learning_rate=0.05, n_estimators=200;, score=0.843 total time=   0.6s
# [CV 5/5] END learning_rate=0.05, n_estimators=200;, score=0.821 total time=   0.7s
# [CV 1/5] END learning_rate=0.05, n_estimators=300;, score=0.881 total time=   1.0s
# [CV 2/5] END learning_rate=0.05, n_estimators=300;, score=0.896 total time=   1.1s
# [CV 3/5] END learning_rate=0.05, n_estimators=300;, score=0.828 total time=   1.1s
# [CV 4/5] END learning_rate=0.05, n_estimators=300;, score=0.836 total time=   1.0s
# [CV 5/5] END learning_rate=0.05, n_estimators=300;, score=0.821 total time=   1.0s
# [CV 1/5] END learning_rate=0.2, n_estimators=100;, score=0.888 total time=   0.3s
# [CV 2/5] END learning_rate=0.2, n_estimators=100;, score=0.881 total time=   0.3s
# [CV 3/5] END learning_rate=0.2, n_estimators=100;, score=0.821 total time=   0.3s
# [CV 4/5] END learning_rate=0.2, n_estimators=100;, score=0.806 total time=   0.3s
# [CV 5/5] END learning_rate=0.2, n_estimators=100;, score=0.828 total time=   0.3s
# [CV 1/5] END learning_rate=0.2, n_estimators=200;, score=0.881 total time=   0.6s
# [CV 2/5] END learning_rate=0.2, n_estimators=200;, score=0.866 total time=   0.7s
# [CV 3/5] END learning_rate=0.2, n_estimators=200;, score=0.836 total time=   0.6s
# [CV 4/5] END learning_rate=0.2, n_estimators=200;, score=0.851 total time=   0.6s
# [CV 5/5] END learning_rate=0.2, n_estimators=200;, score=0.828 total time=   0.6s
# [CV 1/5] END learning_rate=0.2, n_estimators=300;, score=0.873 total time=   1.0s
# [CV 2/5] END learning_rate=0.2, n_estimators=300;, score=0.866 total time=   1.0s
# [CV 3/5] END learning_rate=0.2, n_estimators=300;, score=0.821 total time=   1.0s
# [CV 4/5] END learning_rate=0.2, n_estimators=300;, score=0.821 total time=   1.0s
# [CV 5/5] END learning_rate=0.2, n_estimators=300;, score=0.836 total time=   1.0s
# GridSearchCV(cv=5, estimator=GradientBoostingClassifier(),
#              param_grid={'learning_rate': [0.01, 0.1, 0.05, 0.2],
#                          'n_estimators': [100, 200, 300]},
#              verbose=3)

# %%
grid_search.best_params_
# Out:
# {'learning_rate': 0.01, 'n_estimators': 300}

# %%
best_model = grid_search.best_estimator_
y_pred_tuned = best_model.predict(X_test)

# Evaluate the tuned model
print("Tuned model performance:")
print(f"Accuracy: {accuracy_score(y_test, y_pred_tuned)}")
print("Classification Report:")
print(classification_report(y_test, y_pred_tuned))
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred_tuned))
# Out:
# Tuned model performance:
# Accuracy: 0.8515151515151516
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.83      0.85      0.84       154
#            1       0.87      0.85      0.86       176
#
#     accuracy                           0.85       330
#    macro avg       0.85      0.85      0.85       330
# weighted avg       0.85      0.85      0.85       330
#
# Confusion Matrix:
# [[131  23]
#  [ 26 150]]

# %%
#gradient boosting regressor
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %%
# Generate dataset
X, y = make_regression(n_samples=1000, n_features=2, noise=10, random_state=42)

# Split dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
regressor = GradientBoostingRegressor()
regressor.fit(X_train, y_train)
# Out:
# GradientBoostingRegressor()

# %%
y_pred = regressor.predict(X_test)

# Evaluate the model
print("Current model performance:")
print(f"R2 score: {r2_score(y_test, y_pred)}")
print(f"Mean Absolute Error: {mean_absolute_error(y_test, y_pred)}")
print(f"Mean Squared Error: {mean_squared_error(y_test, y_pred)}")
# Out:
# Current model performance:
# R2 score: 0.9316538349628153
# Mean Absolute Error: 8.430710004457804
# Mean Squared Error: 107.45084354339225

# %%
#do the hyperparameter tuning
from sklearn.model_selection import GridSearchCV

# Define the parameter grid
param_grid = {
    'n_estimators': [100, 200, 300],
    'learning_rate': [0.01, 0.1, 0.05, 0.2],
#     'max_depth': [3, 4, 5],
#     'subsample': [0.8, 0.9, 1.0],
#     'min_samples_split': [2, 5, 10],
#     'min_samples_leaf': [1, 2, 4]
}

gbr = GradientBoostingRegressor()

# %%
gbr
# Out:
# GradientBoostingRegressor()

# %%
grid_search = GridSearchCV(estimator=gbr, param_grid=param_grid, cv = 5, verbose=3)

# %%
grid_search
# Out:
# GridSearchCV(cv=5, estimator=GradientBoostingRegressor(),
#              param_grid={'learning_rate': [0.01, 0.1, 0.05, 0.2],
#                          'n_estimators': [100, 200, 300]},
#              verbose=3)

# %%
grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV 1/5] END learning_rate=0.01, n_estimators=100;, score=0.773 total time=   0.0s
# [CV 2/5] END learning_rate=0.01, n_estimators=100;, score=0.774 total time=   0.0s
# [CV 3/5] END learning_rate=0.01, n_estimators=100;, score=0.776 total time=   0.0s
# [CV 4/5] END learning_rate=0.01, n_estimators=100;, score=0.790 total time=   0.0s
# [CV 5/5] END learning_rate=0.01, n_estimators=100;, score=0.783 total time=   0.0s
# [CV 1/5] END learning_rate=0.01, n_estimators=200;, score=0.902 total time=   0.0s
# [CV 2/5] END learning_rate=0.01, n_estimators=200;, score=0.898 total time=   0.0s
# [CV 3/5] END learning_rate=0.01, n_estimators=200;, score=0.900 total time=   0.0s
# [CV 4/5] END learning_rate=0.01, n_estimators=200;, score=0.917 total time=   0.0s
# [CV 5/5] END learning_rate=0.01, n_estimators=200;, score=0.904 total time=   0.0s
# [CV 1/5] END learning_rate=0.01, n_estimators=300;, score=0.925 total time=   0.1s
# [CV 2/5] END learning_rate=0.01, n_estimators=300;, score=0.923 total time=   0.1s
# [CV 3/5] END learning_rate=0.01, n_estimators=300;, score=0.926 total time=   0.1s
# [CV 4/5] END learning_rate=0.01, n_estimators=300;, score=0.940 total time=   0.1s
# [CV 5/5] END learning_rate=0.01, n_estimators=300;, score=0.919 total time=   0.1s
# [CV 1/5] END learning_rate=0.1, n_estimators=100;, score=0.932 total time=   0.0s
# [CV 2/5] END learning_rate=0.1, n_estimators=100;, score=0.932 total time=   0.0s
# [CV 3/5] END learning_rate=0.1, n_estimators=100;, score=0.938 total time=   0.0s
# [CV 4/5] END learning_rate=0.1, n_estimators=100;, score=0.948 total time=   0.0s
# [CV 5/5] END learning_rate=0.1, n_estimators=100;, score=0.914 total time=   0.0s
# [CV 1/5] END learning_rate=0.1, n_estimators=200;, score=0.925 total time=   0.0s
# [CV 2/5] END learning_rate=0.1, n_estimators=200;, score=0.933 total time=   0.0s
# [CV 3/5] END learning_rate=0.1, n_estimators=200;, score=0.935 total time=   0.0s
# [CV 4/5] END learning_rate=0.1, n_estimators=200;, score=0.947 total time=   0.0s
# [CV 5/5] END learning_rate=0.1, n_estimators=200;, score=0.909 total time=   0.0s
# [CV 1/5] END learning_rate=0.1, n_estimators=300;, score=0.923 total time=   0.1s
# [CV 2/5] END learning_rate=0.1, n_estimators=300;, score=0.932 total time=   0.1s
# [CV 3/5] END learning_rate=0.1, n_estimators=300;, score=0.934 total time=   0.1s
# [CV 4/5] END learning_rate=0.1, n_estimators=300;, score=0.945 total time=   0.1s
# [CV 5/5] END learning_rate=0.1, n_estimators=300;, score=0.904 total time=   0.1s
# [CV 1/5] END learning_rate=0.05, n_estimators=100;, score=0.931 total time=   0.0s
# [CV 2/5] END learning_rate=0.05, n_estimators=100;, score=0.932 total time=   0.0s
# [CV 3/5] END learning_rate=0.05, n_estimators=100;, score=0.935 total time=   0.0s
# [CV 4/5] END learning_rate=0.05, n_estimators=100;, score=0.946 total time=   0.0s
# [CV 5/5] END learning_rate=0.05, n_estimators=100;, score=0.919 total time=   0.0s
# [CV 1/5] END learning_rate=0.05, n_estimators=200;, score=0.931 total time=   0.0s
# [CV 2/5] END learning_rate=0.05, n_estimators=200;, score=0.934 total time=   0.0s
# [CV 3/5] END learning_rate=0.05, n_estimators=200;, score=0.937 total time=   0.0s
# [CV 4/5] END learning_rate=0.05, n_estimators=200;, score=0.947 total time=   0.0s
# [CV 5/5] END learning_rate=0.05, n_estimators=200;, score=0.913 total time=   0.0s
# [CV 1/5] END learning_rate=0.05, n_estimators=300;, score=0.929 total time=   0.1s
# [CV 2/5] END learning_rate=0.05, n_estimators=300;, score=0.932 total time=   0.1s
# [CV 3/5] END learning_rate=0.05, n_estimators=300;, score=0.936 total time=   0.1s
# [CV 4/5] END learning_rate=0.05, n_estimators=300;, score=0.946 total time=   0.1s
# [CV 5/5] END learning_rate=0.05, n_estimators=300;, score=0.911 total time=   0.1s
# [CV 1/5] END learning_rate=0.2, n_estimators=100;, score=0.925 total time=   0.0s
# [CV 2/5] END learning_rate=0.2, n_estimators=100;, score=0.933 total time=   0.0s
# [CV 3/5] END learning_rate=0.2, n_estimators=100;, score=0.936 total time=   0.0s
# [CV 4/5] END learning_rate=0.2, n_estimators=100;, score=0.945 total time=   0.0s
# [CV 5/5] END learning_rate=0.2, n_estimators=100;, score=0.907 total time=   0.0s
# [CV 1/5] END learning_rate=0.2, n_estimators=200;, score=0.918 total time=   0.0s
# [CV 2/5] END learning_rate=0.2, n_estimators=200;, score=0.931 total time=   0.0s
# [CV 3/5] END learning_rate=0.2, n_estimators=200;, score=0.931 total time=   0.0s
# [CV 4/5] END learning_rate=0.2, n_estimators=200;, score=0.942 total time=   0.0s
# [CV 5/5] END learning_rate=0.2, n_estimators=200;, score=0.900 total time=   0.0s
# [CV 1/5] END learning_rate=0.2, n_estimators=300;, score=0.911 total time=   0.1s
# [CV 2/5] END learning_rate=0.2, n_estimators=300;, score=0.928 total time=   0.1s
# [CV 3/5] END learning_rate=0.2, n_estimators=300;, score=0.928 total time=   0.1s
# [CV 4/5] END learning_rate=0.2, n_estimators=300;, score=0.939 total time=   0.1s
# [CV 5/5] END learning_rate=0.2, n_estimators=300;, score=0.897 total time=   0.1s
# GridSearchCV(cv=5, estimator=GradientBoostingRegressor(),
#              param_grid={'learning_rate': [0.01, 0.1, 0.05, 0.2],
#                          'n_estimators': [100, 200, 300]},
#              verbose=3)

# %%
grid_search.best_params_
# Out:
# {'learning_rate': 0.1, 'n_estimators': 100}

# %%
best_model = grid_search.best_estimator_
y_pred_tuned = best_model.predict(X_test)

# Evaluate the tuned model
print("Tuned model performance:")
print(f"R2 score: {r2_score(y_test, y_pred_tuned)}")
print(f"Mean Absolute Error: {mean_absolute_error(y_test, y_pred_tuned)}")
print(f"Mean Squared Error: {mean_squared_error(y_test, y_pred_tuned)}")
# Out:
# Tuned model performance:
# R2 score: 0.9315685401214219
# Mean Absolute Error: 8.433178158109149
# Mean Squared Error: 107.58494035266658
